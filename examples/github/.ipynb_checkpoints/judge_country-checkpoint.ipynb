# %%
with open ('/home/cakgod/code/data/github/contributor_info.txt') as f:
    data = [i.strip().split('|')[4] for i in f.readlines()[1:]]

# %%
with open('/home/cakgod/code/data/country/country_city.xml') as f:
    country_city = [i.strip() for i in f.readlines()]

# %%
with open('/home/cakgod/code/data/country/codelist.txt', encoding='ISO-8859-1') as f:
    codelist_temp = [i.strip().split() for i in f.readlines()]
codelist = [i for i in list(set([i[0].lower() for i in codelist_temp if len(i) > 0])) if i not in ['!', '=', '+', '¦', '#', ]]

# %%
print(sorted(codelist + ['uk', 'usa']))
# Out:
# ['ad', 'ae', 'af', 'ag', 'ai', 'al', 'am', 'ao', 'aq', 'ar', 'as', 'at', 'au', 'aw', 'ax', 'az', 'ba', 'bb', 'bd', 'be', 'bf', 'bg', 'bh', 'bi', 'bj', 'bl', 'bm', 'bn', 'bo', 'bq', 'br', 'bs', 'bt', 'bw', 'by', 'bz', 'ca', 'cc', 'cd', 'cf', 'cg', 'ch', 'ci', 'ck', 'cl', 'cm', 'cn', 'co', 'cr', 'cu', 'cv', 'cw', 'cx', 'cy', 'cz', 'czechia', 'de', 'dj', 'dk', 'dm', 'do', 'dz', 'ec', 'ee', 'eg', 'eh', 'er', 'es', 'et', 'fi', 'fj', 'fk', 'fm', 'fo', 'fr', 'ga', 'gb', 'gd', 'ge', 'gf', 'gg', 'gh', 'gi', 'gl', 'gm', 'gn', 'gp', 'gq', 'gr', 'gs', 'gt', 'gu', 'gw', 'gy', 'hk', 'hm', 'hn', 'hr', 'ht', 'hu', 'id', 'ie', 'il', 'im', 'in', 'io', 'iq', 'ir', 'is', 'it', 'je', 'jm', 'jo', 'jp', 'ke', 'kg', 'kh', 'ki', 'km', 'kn', 'kp', 'kr', 'kw', 'ky', 'kz', 'la', 'lb', 'lc', 'li', 'lk', 'lr', 'ls', 'lt', 'lu', 'lv', 'ly', 'ma', 'mc', 'md', 'me', 'mf', 'mg', 'mh', 'mk', 'ml', 'mm', 'mn', 'mo', 'mp', 'mq', 'mr', 'ms', 'mt', 'mu', 'mv', 'mw', 'mx', 'my', 'mz', 'na', 'nc', 'ne', 'nf', 'ng', 'ni', 'nl', 'no', 'np', 'nr', 'nu', 'nz', 'om', 'pa', 'pe', 'pf', 'pg', 'ph', 'pk', 'pl', 'pm', 'pn', 'pr', 'ps', 'pt', 'pw', 'py', 'qa', 're', 'ro', 'rs', 'ru', 'rw', 'sa', 'sb', 'sc', 'sd', 'se', 'sg', 'sh', 'si', 'sj', 'sk', 'sl', 'sm', 'sn', 'so', 'sr', 'ss', 'st', 'sv', 'sx', 'sy', 'sz', 'tc', 'td', 'tf', 'tg', 'th', 'tj', 'tk', 'tl', 'tm', 'tn', 'to', 'tr', 'tt', 'tv', 'tw', 'tz', 'ua', 'ug', 'uk', 'um', 'us', 'usa', 'uy', 'uz', 'va', 'vc', 've', 'vg', 'vi', 'vn', 'vu', 'wf', 'ws', 'x', 'xz', 'ye', 'yt', 'za', 'zm', 'zw']

# %%
from xml.etree.ElementTree import parse
doc = parse('/home/cakgod/code/data/country/country_city.xml')

# %%
country_state_city_dict = {}

root = doc.getroot()
for i in root:
    country_name = i.attrib['Name']
    country_state_city_dict[country_name] = {}
    try:
        for j in i:            
            if j.attrib == {}:
                state_name = 'None'
            else:
                state_name = j.attrib['Name']
            country_state_city_dict[country_name][state_name] = []
            
            try:
                for k in j:
                    city_name = k.attrib['Name']
                    country_state_city_dict[country_name][state_name].append(city_name)
            except:
                continue
            
    except:
        state_name = 'None'
        country_state_city_dict[country_name][state_name] = []
        print('There are not any states')
        continue

# %%
print(country_state_city_dict['China'])
# Out:
# {'Anhui': ['Anqing', 'Bengbu', 'Bozhou', 'Chizhou', 'Chuzhou', 'Fuyang', 'Hefei', 'Huaibei', 'Huainan', 'Huangshan', "Lu'an", "Ma'anshan", 'Suzhou', 'Tongling', 'Wuhu', 'Xuancheng'], 'Beijing': ['Changping', 'Chaoyang', 'Chongwen', 'Daxing', 'Dongcheng', 'Fangshan', 'Fengtai', 'Haidian', 'Huairou', 'Mentougou', 'Miyun', 'Pinggu', 'Shijingshan', 'Shunyi', 'Tongzhou', 'Xicheng', 'Yanqing'], 'Chongqing': ["Ba'nan", 'Beibei', 'Bishan', 'Changshou', 'Chengkou', 'Dadukou', 'Dazu', 'Dianjiang', 'Fengdu', 'Fengjie', 'Fuling', 'Hechuan', 'Jiangbei', 'Jiangjin', 'Jiulongpo', 'Kaixian', 'Kaixian', 'Liangping', "Nan'an", 'Liangjiangxinqu', 'Pengshui Miao-Tujia Autonomous Country', 'Qianjiang', 'Qijiang', 'Rongchang', 'Shapingba', 'Shizhu Tujia Autonomous Country', 'Shuangqiao', 'Tongliang', 'Tongnan', 'Wansheng', 'Wanzhou', 'Wulong', 'Wushan', 'Wuxi', 'Xiushan Tujia-Miao Autonomous Country', 'Yongchuan', 'Youyang Tujia-Miao Autonomous Country', 'Yubei', 'Yunyang', 'Yuzhong', 'Zhongxian'], 'Fujian': ['Fuzhou', 'Longyan', 'Nanping', 'Ningde', 'Putian', 'Quanzhou', 'Sanming', 'Xiamen', 'Zhangzhou'], 'Gansu': ['Baiyin', 'Dingxi', 'Gannan Tibetan Autonomous Prefecture', 'Jiayuguan', 'Jinchang', 'Jiuquan', 'Lanzhou', 'Linxia Hui Autonomous Prefecture', 'Longnan', 'Pingliang', 'Qingyang', 'Tianshui', 'Wuwei', 'Zhangye'], 'Guangdong': ['Chaozhou', 'Dongguan', 'Foshan', 'Guangzhou', 'Heyuan', 'Huizhou', 'Jiangmen', 'Jieyang', 'Maoming', 'Meizhou', 'Qingyuan', 'Shantou', 'Shanwei', 'Shaoguan', 'Shenzhen', 'Yangjiang', 'Yunfu', 'Zhanjiang', 'Zhaoqing', 'Zhongshan', 'Zhuhai'], 'Guangxi': ['Baise', 'Beihai', 'Chongzuo', 'Fangchenggang', 'Guigang', 'Guilin', 'Hechi', 'Hezhou', 'Laibin', 'Liuzhou', 'Nanning', 'Qinzhou', 'Wuzhou', 'Yulin'], 'Guizhou': ['Anshun', 'Bijie', 'Guiyang', 'Liupanshui', 'Qiandongnan Miao-Dong Autonomous Prefecture', 'Qiannan Buyi Autonomous Prefecture', 'Qianxinan Buyi-Miao Autonomous Prefecture', 'Tongren', 'Zunyi'], 'Hainan': ['Baisha Li Autonomous County', 'Baoting Li-Miao Autonomous County', 'Cengmai', 'Danzhou', "Ding'an", 'Dongfang', 'Haikou', 'Jiang Li Autonomous County', 'Ledong Li Autonomous County', 'Lingao', 'Lingshui Li Autonomous County', 'Qionghai', 'Qiongzhong Li-Miao Autonomous County', 'Shansha', 'Sanya', 'Tunchang', 'Wanning', 'Wenchang', 'Wuzhishan'], 'Hebei': ['Baoding', 'Cangzhou', 'Chengde', 'Handan', 'Hengshui', 'Langfang', 'Qinhuangdao', 'Shijiazhuang', 'Tangshan', 'Xingtai', 'Zhangjiakou'], 'Heilongjiang': ['Da Hinggan Ling', 'Daqing', 'Harbin', 'Hegang', 'Heihe', 'Jiamusi', 'Jixi', 'Mudanjiang', 'Qiqihar', 'Qitaihe', 'Shuangyashan', 'Suihua', 'Yichun'], 'Henan': ['Anyang', 'Hebi', 'Jiaozuo', 'Jiyuan', 'Kaifeng', 'Luohe', 'Luoyang', 'Nanyang', 'Pingdingshan', 'Puyang', 'Sanmenxia', 'Shangqiu', 'Xinxiang', 'Xinyang', 'Xuchang', 'Zhengzhou', 'Zhoukou', 'Zhumadian'], 'Hongkong SAR': [], 'Hubei': ['Enshi Tujia-Miao Autonomous Prefecture', 'Ezhou', 'Huanggang', 'Huangshi', 'Jingmen', 'Jingzhou', 'Qianjiang', 'Shennongjia', 'Shiyan', 'Suizhou', 'Tianmen', 'Wuhan', 'Xiangyang', 'Xianning', 'Xiantao', 'Xiaogan', 'Yichang'], 'Hunan': ['Changde', 'Changsha', 'Chenzhou', 'Hengyang', 'Huaihua', 'Loudi', 'Shaoyang', 'Xiangtan', 'Xiangxi Tujia-Miao Autonomous Prefecture', 'Yiyang', 'Yongzhou', 'Yueyang', 'Zhangjiajie', 'Zhuzhou'], 'Inner Mongolia': ['Alxa', 'Baotou', 'Bayannur', 'Chifeng', 'Hohhot', 'Hulun Buir', 'Ordos', 'Tongliao', 'Ulan Qab', 'Wuhai', 'Xilin Gol', "Xing'an"], 'Jiangsu': ['Changzhou', "Huai'an", 'Lianyungang', 'Nanjing', 'Nantong', 'Suqian', 'Suzhou', 'Taizhou', 'Wuxi', 'Xuzhou', 'Yancheng', 'Yangzhou', 'Zhenjiang'], 'Jiangxi': ['Fuzhou', 'Ganzhou', "Ji'an", 'Jingdezhen', 'Jiujiang', 'Nanchang', 'Pingxiang', 'Shangrao', 'Xinyu', 'Yichun', 'Yingtan'], 'Jilin': ['Baicheng', 'Baishan', 'Changchun', 'Jilin', 'Liaoyuan', 'Siping', 'Songyuan', 'Tonghua', 'Yanbian Korean Autonomous Prefecture'], 'Liaoning': ['Anshan', 'Benxi', 'Chaoyang', 'Dalian', 'Dandong', 'Fushun', 'Fuxin', 'Huludao', 'Jinzhou', 'Liaoy ...

# %%
country_name = [' '.join([j.lower() for j in i.split()]) for i in list(country_state_city_dict.keys())]
print(len(country_name))
print(country_name)
# Out:
# 240
# ['afghanistan', 'aland lslands', 'albania', 'algeria', 'american samoa', 'andorra', 'angola', 'anguilla', 'antarctica', 'antigua and barbuda', 'argentina', 'armenia', 'aruba', 'ascension island', 'australia', 'austria', 'azerbaijan', 'bahamas', 'bahrain', 'bangladesh', 'barbados', 'belgium', 'belize', 'benin', 'bermuda', 'bhutan', 'bolivia', 'bosnia and herzegovina', 'botswana', 'bouvet island', 'brazil', 'british indian ocean territory', 'brunei', 'bulgaria', 'burkina faso', 'burundi', 'cambodia', 'cameroon', 'canada', 'cape verde', 'cayman islands', 'central african republic', 'chad', 'chile', 'china', 'christmas island', 'cocos(keeling)islands', 'colombia', 'comoros', 'congo', 'congo(drc)', 'cook islands', 'costa rica', "cote d'ivoire", 'croatia', 'cuba', 'cyprus', 'czech republic', 'denmark', 'djibouti', 'dominica', 'dominican republic', 'ecuador', 'egypt', 'el salvador', 'eritrea', 'estonia', 'ethiopia', 'falkland islands', 'faroe islands', 'fiji islands', 'finland', 'france', 'frech polynesia', 'french guiana', 'french southern and antarctic lands', 'gabon', 'gambia', 'georgia', 'germany', 'ghana', 'gibraltar', 'greece', 'greenland', 'grenada', 'guadeloupe', 'guam', 'guatemala', 'guernsey', 'guinea', 'guinea-bissau', 'guyana', 'haiti', 'heard island and mcdonald islands', 'honduras', 'hungary', 'iceland', 'india', 'indonesia', 'iran', 'iraq', 'ireland', 'isle of man', 'israel', 'italy', 'jamaica', 'japan', 'jersey', 'jordan', 'kazakhstan', 'kenya', 'kiribati', 'korea', 'kuwait', 'kyrgyzstan', 'laos', 'latvia', 'lebanon', 'lesotho', 'liberia', 'libya', 'liechtenstein', 'lithuania', 'luxembourg', 'macedonia,former yugoslav republic of', 'madagascar', 'malawi', 'malaysia', 'maldives', 'mali', 'malta', 'marshall islands', 'martinique', 'mauritania', 'mauritius', 'mayotte', 'mexico', 'micronesia', 'moldova', 'monaco', 'mongolia', 'montserrat', 'morocco', 'mozambique', 'myanmar', 'namibia', 'nauru', 'nepal', 'netherlands', 'netherlands antilles', 'new caledonia', 'new zealand', 'nicaragua', 'niger', 'nigeria', 'niue', 'norfolk island', 'north korea', 'northern mariana islands', 'norway', 'oman', 'pakistan', 'palau', 'palestinian authority', 'panama', 'papua new guinea', 'paraguay', 'peru', 'philippines', 'pitcairn islands', 'poland', 'portugal', 'puerto rico', 'qatar', 'reunion', 'romania', 'russia', 'rwanda', 'samoa', 'san marino', 'sao tome and principe', 'saudi arabia', 'senegal', 'serbia,montenegro', 'seychelles', 'sierra leone', 'singapore', 'slovakia', 'slovenia', 'solomon islands', 'somalia', 'south africa', 'south georgia and south sandwich islands', 'spain', 'sri lanka', 'st.helena', 'st.kitts and nevis', 'st.lucia', 'st.pierre and miquelon', 'st.vincent and the grenadines', 'sudan', 'suriname', 'svalbard and jan mayen', 'swaziland', 'sweden', 'switzerland', 'syria', 'tajikistan', 'tanzania', 'thailand', 'timor-leste', 'togo', 'tokelau', 'tonga', 'trinidad and tobago', 'tristan da cunha', 'tunisia', 'turkey', 'turkmenistan', 'turks and caicos islands', 'tuvalu', 'uganda', 'ukraine', 'united arab emirates', 'united kingdom', 'united states', 'united states minor outlying islands', 'uruguay', 'uzbekistan', 'vanuatu', 'vatican city', 'venezuela', 'vietnam', 'virgin islands', 'virgin islands,british', 'wallis and futuna', 'white russia', 'yemen', 'zambia', 'zimbabwe']

# %%
state_name_temp = []
for k, v in country_state_city_dict.items():
    if v == {}:
        continue
    state_name_temp += list(v.keys())
state_name = [' '.join(i.split()).lower() for i in list(set(state_name_temp))]
print(state_name)
# Out:
# ['indiana', 'vermont', 'nevada', 'south carolina', 'colorado', 'virginia', 'shaanxi', 'canberra', 'hawaii', 'jilin', 'zhejiang', 'anhui', 'guangdong', 'connecticut', 'kelantan', 'wisconsin', 'seoul', 'jiangsu', 'south australia', 'hunan', 'daejeon', 'taiwan', 'shanghai', 'georgia', 'minnesota', 'utah', 'maryland', 'daegu', 'alaska', 'tianjin', 'yunnan', 'gyeonggi-do', 'massachusetts', 'district of columbia', 'gansu', 'northern ireland', 'beijing', 'maine', 'new jersey', 'california', 'kuala lumpur', 'idaho', 'gangwon-do', 'shanxi', 'west virginia', 'tasmania', 'alabama', 'england', 'new hampshire', 'gyeongsangbuk-do', 'xinjiang', 'hebei', 'new mexico', 'ohio', 'illinois', 'arkansas', 'louisiana', 'kentucky', 'montana', 'tibet', 'wyoming', 'north carolina', 'victoria', 'heilongjiang', 'shandong', 'florida', 'guangxi', 'inner mongolia', 'busan', 'north dakota', 'malacca', 'gyeongsangnam-do', 'guizhou', 'incheon', 'sichuan', 'negeri sembilan', 'jeollanam-do', 'selangor', 'oregon', 'perlis', 'south dakota', 'kansas', 'new york', 'missouri', 'liaoning', 'johor', 'sarawak', 'nebraska', 'henan', 'new south wales', 'ningxia', 'hongkong sar', 'chungcheongbuk-do', 'tennessee', 'rhode island', 'washington', 'macao sar', 'pahang', 'michigan', 'pennsylvania', 'labuan', 'jeju-do', 'arizona', 'western australia', 'wales', 'none', 'gwangju', 'hubei', 'oklahoma', 'texas', 'qinghai', 'hainan', 'jiangxi', 'queensland', 'mississippi', 'northern territory', 'delaware', 'perak', 'jeollabuk-do', 'chongqing', 'pulau pinang', 'fujian', 'iowa', 'ulsan', 'scotland', 'sabah', 'terengganu', 'chungcheongnam-do', 'kedah']

# %%
city_name_temp = []
for k, v in country_state_city_dict.items():
    if v == {}:
        continue
    for k1, v1 in v.items():
        city_name_temp += v1
city_name = [' '.join(i.split()).lower() for i in list(set(city_name_temp))]
print(city_name)
# Out:
# ['mainz', 'leitrim', 'viqueque', 'skikda', 'rapid city', 'bat yam', 'secunda', 'gurye county', 'nowy sacz', 'danyang county', 'buri ram', 'fejer', 'kyzyl', 'muskegon', 'sonsonate', 'le kef', 'tash-kumyr', 'guangyuan', 'kinabatangan', "tai'an", 'naxcivan', 'kirov', 'rosario', 'ngari', 'woleu-ntem', 'anzoategui', 'edirne', 'govi-altay', 'salerno', 'soroti', 'rize', 'borsod-abauj-zemplen', 'greater accra', 'kitui', 'san juan', 'datong', 'hongqiao', 'shizhu tujia autonomous country', 'vlore', 'bozhou', 'luliang', 'ede', 'vlaams-brabant', 'dara', 'tel aviv-yafo', 'kazan', 'takev', 'wuwei', 'splitsko-dalmatinska', 'huanuco', 'st. catherine', 'honiara', 'amazonas', 'suncheon', 'st. andrews', 'albacete', 'saint paul', 'gisborne', 'gaziantep', 'ogres', 'pekan', 'basse-kotto', 'caen', 'heves', 'piura', 'hartford', 'kampong spoe', 'peoria', 'craiova', 'khulna', 'kirundo', 'kohima', 'podravska', 'aarhus', 'sal', 'nusa tenggara barat', 'chin', 'xianning', 'minas gerais', 'bogota', 'mouhoun', 'hebei', 'kindia', 'valencia', 'rennell and bellona', 'kayunga', 'xiaogan', 'changnyeong county', 'acre', 'dianjiang', 'margibi', 'alto tros-os-montes', 'wele-nzas', 'choloma', 'mtwara', 'oshawa', 'kosi', 'perm', 'usak', 'espirito santo', 'arkalyk', 'huancavelica', "lu'an", 'nagasaki', 'dushanbe', 'preilu', 'wolverhampton', 'st helens', 'mannar', 'mosteiros', 'kiel', 'soria', 'liberecky', 'gunsan', 'tokyo', 'bjelovarsko-bilogorska', 'wuhan', 'bubanza', 'ayeyarwady', 'gorenjska', 'tongyeong', 'stirling', 'yushu tibetan autonomous prefecture', 'adana', 'dadukou', 'paysandu', 'huizhou', 'changde', 'respublika krym', 'york', 'tillaberi', 'moyo', 'bahia blanca', 'erzurum', 'huludao', 'batna', 'springbok', 'aydin', 'syracuse', 'roi et', 'beersheba', 'nuevo laredo', 'teluk intan', 'eugene', 'paraiba', 'pendzhikent', 'sucre', 'shaoxing', 'yamanashi', 'goseong county', 'mashonaland west', 'hutchinson', 'littoral', 'samsun', 'ludzas', 'frederiksborg', 'spokane', 'lisakovsk', 'nyamira', 'fuxin', 'indore', 'quetzaltenango', 'balitmore', 'soenderjylland', 'ad dawhah', 'ulundi', 'tunis', 'spring hill', 'mianyang', 'aqtobe', 'firenze', 'balkhash', 'nantes', 'swietochłowice', 'santo antao', 'ordu', 'laane', 'lunda norte', 'bougouriba', 'giyani', 'dakar', 'gloucester', 'boulkiemde', 'obwalden', 'osh', 'aileu', 'philadephia', 'alentejo central', 'alta verapaz', 'chai nat', 'wonju', 'kuala penyu', 'hannover', 'taitung county', 'soum', 'bukit mertajam', 'gagaifomauga', 'krong preah', 'artvin', 'kutahya', 'shefa', 'beibei', 'gabes', 'chiayi city', 'viterbo', 'zyryanovsk', 'fargona', 'chanion', 'kharkiv', 'priaraks', 'upolu', 'ngozi', 'taiping', 'tamega', 'juneau', 'rilinsky', 'cavan', 'moyen-ogooue', 'palana', 'manatuto', 'badajoz', 'tagant', 'licko-senjska', 'pathum thani', 'magdalena', 'lanzhou', 'kyrenia', 'maan', 'balvu', 'carbondale', 'changning', 'tampico', 'casablanca', 'ziguinchor', 'al-jawf', 'greymouth', 'guoluo tibetan autonomous prefecture', 'przemysl', 'kidal', 'santander', 'santa catarina', 'leavenworth', 'heyuan', 'kegalle', 'varazdinska', 'san martin', 'khon kaen', 'bimbo', 'atlantico sur', 'vaslui', 'st. peterburg', 'moyen-comoe', 'santa barbara', "al l'ayn", 'al-mubarraz', 'kuldigas', 'yala', 'huaibei', 'jerantut', 'guipuzcoa', 'lexington', 'atua', 'sullana', 'al-batinah', 'bayreuth', 'dazhou', 'bazega', 'nurek', 'nagano', 'madurai', 'shanwei', 'tula', 'puntarenas', 'lira', 'pitas', 'diu', 'meru', 'donga', 'khomas', 'boaco', 'treinta y tres', 'yanqing', 'loroum', 'spodnjeposavska', 'bydgoszcz', 'ngounie', 'portsmouth', 'gliwice', 'canterbury', 'la rioja', 'jiaxing', 'jangseong county', 'maseru', 'zhuzhou', 'xrimnicu vilcea', 'vicksburg', 'sungai siput', 'nordjylland', 'pawtucket', 'zhengzhou', 'sokcho', 'vicebskaja', 'zinder', 'witsieshoek', 'wroclaw', 'chifeng', 'san luis potosi', 'jieyang', 'dhamar', 'yangjiang', 'arua', 'pingdingshan', 'stann creek', 'kaolack', 'chalons-en-champagne', 'soltustik qazaqstan', 'kota setar', 'rongchang', 'al-bayda', 'jinch ...

# %%
import re

# %%
none_num = 0
judge_by_country_num = 0
judge_by_country_code_num = 0
judge_by_state_num = 0
judge_by_city_num = 0

for i in data:
    # judge by none
    if i == 'None':
        none_num += 1
        continue
    #location_split = [j.strip().lower() for j in i.split(',')]
    #location_split = [j.strip().lower() for j in re.split(r'/., ', i)]
    # judge by country name
    judge_by_country = list(set(location_split).intersection(set(country_name)))
    if judge_by_country != []:
        judge_by_country_num += 1
        continue
    # judge by country code
    judge_by_country_code = list(set(location_split).intersection(set(codelist)))
    if judge_by_country_code != []:
        judge_by_country_code_num += 1
        continue
    # judge by state name
    judge_by_state = list(set(location_split).intersection(set(state_name)))
    if judge_by_state != []:
        judge_by_state_num += 1
        continue
    # judge by state name
    judge_by_city = list(set(location_split).intersection(set(city_name)))
    if judge_by_city != []:
        judge_by_city_num += 1
        continue
    #print(i)
    
    
print(len(data))
print(none_num)
print(judge_by_country_num)
print(judge_by_country_code_num)
print(judge_by_state_num)
print(judge_by_city_num)
# Out:
# 34720
# 13299
# 2750
# 69
# 952
# 3111
